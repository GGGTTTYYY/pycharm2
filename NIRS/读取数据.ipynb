# %%
import xlrd
import pandas as pd
nir = pd.read_excel("大米蛋白粉.xlsx")  # 默认导入第一个表格
data = nir.head()
print(data)
lihua = pd.read_excel("大米蛋白粉.xlsx",sheet_name="理化值")
data2 = lihua.head()
print(data2)
print(type(nir))
# Out:
#    波长(nm)  吸光度(SupNIR-2720D68大米蛋白粉2014037_20140902092928.ripx)  \
# 0    1000                                           0.165739
# 1    1001                                           0.165809
# 2    1002                                           0.165855
# 3    1003                                           0.166004
# 4    1004                                           0.166186
#
#    吸光度(SupNIR-2720D68大米蛋白粉2014037_20140902093223.ripx)  \
# 0                                           0.166618
# 1                                           0.166733
# 2                                           0.166711
# 3                                           0.166856
# 4                                           0.167036
#
#    吸光度(SupNIR-2720D68大米蛋白粉2014029_20140902140851.ripx)  \
# 0                                           0.167848
# 1                                           0.167875
# 2                                           0.168103
# ...
